# %%
import pandas as pd
from sqlalchemy import create_engine

# Load the csv_hospitalreports1620_odp CSV file
df_1 = pd.read_csv('/Users/shiveshrajsahu/Desktop/MET CS 689/SahuShivesh_Project/csv_hospitalreports1620_odp.csv')

df_1.head()
# Out:
#    Year   County          Hospital    OSHPDID                 system  \
# 0  2016  Alameda  Alameda Hospital  106010735  Alameda Health System
# 1  2016  Alameda  Alameda Hospital  106010735  Alameda Health System
# 2  2016  Alameda  Alameda Hospital  106010735  Alameda Health System
# 3  2016  Alameda  Alameda Hospital  106010735  Alameda Health System
# 4  2016  Alameda  Alameda Hospital  106010735  Alameda Health System
#
#   Type of Report        Performance Measure  # of Adverse Events  # of Cases  \
# 0            IMI                        AMI                  3.0        17.0
# 1            IMI               Acute Stroke                  9.0        74.0
# 2            IMI   Acute Stroke Hemorrhagic                  5.0         9.0
# 3            IMI      Acute Stroke Ischemic                  4.0        65.0
# 4            IMI  Acute Stroke Subarachnoid                  NaN         NaN
#
#    Risk-adjusted Rate Hospital Ratings  Longitude  Latitude
# ...

# %%
# PostgreSQL connection info
username = 'postgres'
password = 'Shivesh5273'
host = 'localhost' 
port = '5432' 
dbname = 'FinalProject'

# Create SQLAlchemy engine
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{dbname}')

# Import data into PostgreSQL
df_1.to_sql('hospital_dimension', engine, if_exists='replace', index=False)
# Out:
# 277

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load the  CSV file
df_2 = pd.read_csv('/Users/shiveshrajsahu/Desktop/MET CS 689/SahuShivesh_Project/us_hospital_locations.csv')

df_2.head()
# Out:
#               X             Y  FID        ID  \
# 0 -1.331889e+07  4.346975e+06    1   5793230
# 1 -1.322651e+07  4.049626e+06    2  53391362
# 2 -1.315620e+07  4.031978e+06    3  11190023
# 3 -1.317190e+07  4.041752e+06    4  17090028
# 4 -1.313208e+07  4.037270e+06    5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# ...

# %%
# PostgreSQL connection info
username = 'postgres'
password = 'Shivesh5273'
host = 'localhost' 
port = '5432' 
dbname = 'FinalProject'


# Create SQLAlchemy engine
engine = create_engine(f'postgresql://{username}:{password}@{host}:{port}/{dbname}')

# Import data into PostgreSQL
df_2.to_sql('hospital_locations', engine, if_exists='replace', index=False)
# Out:
# 596
